# %% [markdown]
# # 应用该如何选择这些并行的方式

# %% [markdown]
# ## 几种并行方式的总结
# <img src="../asset/parallelism.jpg" width="100%" >

# %% [markdown]
# ## 如何选择这些并行的方法？
# ### I/O密集型(IO-Bound)
# ![](../asset/IOBound.png)

# %% [markdown]
# ### 计算密集型(CPU-Bound)
# ![](../asset/CPUBound.png)

# %% [markdown]
# ### 如何加入I/O密集型的程序

# %%
import requests
import time


def download_site(url, session):
    with session.get(url) as response:
        print(f"Read {len(response.content)} from {url}")


def download_all_sites(sites):
    with requests.Session() as session:
        for url in sites:
            download_site(url, session)


if __name__ == "__main__":
    sites = [
        "https://www.baidu.com",
    ] * 80
    start_time = time.time()
    download_all_sites(sites)
    duration = time.time() - start_time
    print(f"Downloaded {len(sites)} in {duration} seconds")
# Out:
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Downloaded 80 in 0.7354123592376709 seconds

# %% [markdown]
# 改造成多线程的版本

# %%
import concurrent.futures
import requests
import threading
import time


thread_local = threading.local()


def get_session():
    if not hasattr(thread_local, "session"):
        thread_local.session = requests.Session()
    return thread_local.session


def download_site(url):
    session = get_session()
    with session.get(url) as response:
        print(f"Read {len(response.content)} from {url}")


def download_all_sites(sites):
    with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
        executor.map(download_site, sites)


if __name__ == "__main__":
    sites = [
        "https://www.baidu.com",

    ] * 80
    start_time = time.time()
    download_all_sites(sites)
    duration = time.time() - start_time
    print(f"Downloaded {len(sites)} in {duration} seconds")
# Out:
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.comRead 2443 from https://www.baidu.com
#
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.comRead 2443 from https://www.baidu.com
#
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.comRead 2443 from https://www.baidu.com
#
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.comRead 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
#
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.comRead 2443 from https://www.baidu.comRead 2443 from https://www.baidu.com
#
#
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.comRead 2443 from https://www.baidu.com
#
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.comRead 2443 from https://www.baidu.com
#
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.comRead 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
#
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.comRead 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
#
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.comRead 2443 from https://www.baidu.com
#
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.comRead 2443 from https://www.baidu.com
#
# Read 2443 from https://www.baidu.comRead 2443 from https://www.baidu.com
#
# Read 2443 from https://www.baidu.comRead 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
#
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Read 2443 from https://www.baidu.com
# Downloaded 80 in 0.5716183185577393 seconds

# %% [markdown]
# ![](../asset/Threading.png)

# %% [markdown]
# 改造成asyncio的版本

# %%
# %load src/asyncio-aiohttp.py
import asyncio
import time
import aiohttp


async def download_site(session, url):
    async with session.get(url) as response:
        print("Read {0} from {1}".format(response.content_length, url))


async def download_all_sites(sites):
    async with aiohttp.ClientSession() as session:
        tasks = []
        for url in sites:
            task = asyncio.ensure_future(download_site(session, url))
            tasks.append(task)
        await asyncio.gather(*tasks, return_exceptions=True)

if __name__ == "__main__":
    sites = [
            "https://www.baidu.com",

            ] * 80
    start_time = time.time()
    asyncio.get_event_loop().run_until_complete(download_all_sites(sites))
    duration = time.time() - start_time
    print(f"Downloaded {len(sites)} sites in {duration} seconds")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-4f0efaecfadf> in <module>
#      24             ] * 80
#      25     start_time = time.time()
# ---> 26     asyncio.get_event_loop().run_until_complete(download_all_sites(sites))
#      27     duration = time.time() - start_time
#      28     print(f"Downloaded {len(sites)} sites in {duration} seconds")
#
# /opt/conda/lib/python3.7/asyncio/base_events.py in run_until_complete(self, future)
#     568         future.add_done_callback(_run_until_complete_cb)
#     569         try:
# --> 570             self.run_forever()
#     571         except:
#     572             if new_task and future.done() and not future.cancelled():
#
# /opt/conda/lib/python3.7/asyncio/base_events.py in run_forever(self)
#     523         self._check_closed()
#     524         if self.is_running():
# --> 525             raise RuntimeError('This event loop is already running')
#     526         if events._get_running_loop() is not None:
#     527             raise RuntimeError(
#
# RuntimeError: This event loop is already running
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com
# Read 227 from https://www.baidu.com

# %%
# !python src/asyncio-aiohttp.py
# Out:
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 3549 from https://www.jython.org
# Read 278 from http://olympus.realpython.org/dice
# Read 278 from http://olympus.realpython.org/dice
# Downloaded 160 sites in 9.296924352645874 seconds

# %% [markdown]
# ![](../asset/Asyncio.webp)

# %% [markdown]
# 改造成多进程版本

# %%
# %load src/multiprocessing-http.py
import requests
import multiprocessing
import time

session = None


def set_global_session():
    global session
    if not session:
        session = requests.Session()


def download_site(url):
    with session.get(url) as response:
        name = multiprocessing.current_process().name
        print(f"{name}:Read {len(response.content)} from {url}")


def download_all_sites(sites):
    with multiprocessing.Pool(initializer=set_global_session) as pool:
        pool.map(download_site, sites)


if __name__ == "__main__":
    sites = [
        "https://www.jython.org",
        "https://olympus.realpython.org/dice",
    ] * 10
    start_time = time.time()
    download_all_sites(sites)
    duration = time.time() - start_time
    print(f"Downloaded {len(sites)} in {duration} seconds")

# %%
# !python src/multiprocessing-http.py
# Out:
# ForkPoolWorker-9:Read 10267 from https://www.jython.org
# ForkPoolWorker-17:Read 10267 from https://www.jython.org
# ForkPoolWorker-3:Read 10267 from https://www.jython.org
# ForkPoolWorker-5:Read 10267 from https://www.jython.org
# ForkPoolWorker-23:Read 10267 from https://www.jython.org
# ForkPoolWorker-9:Read 10267 from https://www.jython.org
# ForkPoolWorker-20:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-26:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-7:Read 10267 from https://www.jython.org
# ForkPoolWorker-32:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-34:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-56:Read 10267 from https://www.jython.org
# ForkPoolWorker-44:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-2:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-37:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-40:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-48:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-38:Read 10267 from https://www.jython.org
# ForkPoolWorker-55:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-35:Read 10267 from https://www.jython.org
# ForkPoolWorker-26:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-39:Read 10267 from https://www.jython.org
# ForkPoolWorker-33:Read 10267 from https://www.jython.org
# ForkPoolWorker-53:Read 10267 from https://www.jython.org
# ForkPoolWorker-5:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-23:Read 10267 from https://www.jython.org
# ForkPoolWorker-3:Read 10267 from https://www.jython.org
# ForkPoolWorker-15:Read 10267 from https://www.jython.org
# ForkPoolWorker-48:Read 10267 from https://www.jython.org
# ForkPoolWorker-28:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-38:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-57:Read 10267 from https://www.jython.org
# ForkPoolWorker-16:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-33:Read 10267 from https://www.jython.org
# ForkPoolWorker-60:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-6:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-48:Read 10267 from https://www.jython.org
# ForkPoolWorker-25:Read 10267 from https://www.jython.org
# ForkPoolWorker-58:Read 10267 from https://www.jython.org
# ForkPoolWorker-36:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-22:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-64:Read 10267 from https://www.jython.org
# ForkPoolWorker-28:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-48:Read 10267 from https://www.jython.org
# ForkPoolWorker-61:Read 10267 from https://www.jython.org
# ForkPoolWorker-58:Read 10267 from https://www.jython.org
# ForkPoolWorker-23:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-32:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-2:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-24:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-36:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-38:Read 10267 from https://www.jython.org
# ForkPoolWorker-11:Read 10267 from https://www.jython.org
# ForkPoolWorker-19:Read 10267 from https://www.jython.org
# ForkPoolWorker-9:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-40:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-57:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-26:Read 10267 from https://www.jython.org
# ForkPoolWorker-48:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-43:Read 10267 from https://www.jython.org
# ForkPoolWorker-32:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-11:Read 10267 from https://www.jython.org
# ForkPoolWorker-33:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-13:Read 10267 from https://www.jython.org
# ForkPoolWorker-24:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-23:Read 10267 from https://www.jython.org
# ForkPoolWorker-48:Read 10267 from https://www.jython.org
# ForkPoolWorker-38:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-9:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-25:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-4:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-10:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-27:Read 10267 from https://www.jython.org
# ForkPoolWorker-9:Read 10267 from https://www.jython.org
# ForkPoolWorker-48:Read 10267 from https://www.jython.org
# ForkPoolWorker-49:Read 10267 from https://www.jython.org
# ForkPoolWorker-41:Read 10267 from https://www.jython.org
# ForkPoolWorker-5:Read 10267 from https://www.jython.org
# ForkPoolWorker-14:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-59:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-2:Read 10267 from https://www.jython.org
# ForkPoolWorker-21:Read 10267 from https://www.jython.org
# ForkPoolWorker-38:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-42:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-10:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-9:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-13:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-54:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-57:Read 10267 from https://www.jython.org
# ForkPoolWorker-38:Read 10267 from https://www.jython.org
# ForkPoolWorker-30:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-5:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-13:Read 10267 from https://www.jython.org
# ForkPoolWorker-22:Read 10267 from https://www.jython.org
# ForkPoolWorker-61:Read 10267 from https://www.jython.org
# ForkPoolWorker-7:Read 10267 from https://www.jython.org
# ForkPoolWorker-36:Read 10267 from https://www.jython.org
# ForkPoolWorker-34:Read 10267 from https://www.jython.org
# ForkPoolWorker-29:Read 10267 from https://www.jython.org
# ForkPoolWorker-9:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-33:Read 10267 from https://www.jython.org
# ForkPoolWorker-39:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-28:Read 10267 from https://www.jython.org
# ForkPoolWorker-4:Read 10267 from https://www.jython.org
# ForkPoolWorker-20:Read 10267 from https://www.jython.org
# ForkPoolWorker-44:Read 10267 from https://www.jython.org
# ForkPoolWorker-47:Read 10267 from https://www.jython.org
# ForkPoolWorker-57:Read 10267 from https://www.jython.org
# ForkPoolWorker-62:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-26:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-19:Read 10267 from https://www.jython.org
# ForkPoolWorker-61:Read 10267 from https://www.jython.org
# ForkPoolWorker-60:Read 10267 from https://www.jython.org
# ForkPoolWorker-22:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-27:Read 10267 from https://www.jython.org
# ForkPoolWorker-58:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-10:Read 10267 from https://www.jython.org
# ForkPoolWorker-30:Read 10267 from https://www.jython.org
# ForkPoolWorker-12:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-6:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-18:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-59:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-7:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-11:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-48:Read 10267 from https://www.jython.org
# ForkPoolWorker-51:Read 10267 from https://www.jython.org
# ForkPoolWorker-15:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-42:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-55:Read 10267 from https://www.jython.org
# ForkPoolWorker-41:Read 10267 from https://www.jython.org
# ForkPoolWorker-54:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-49:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-35:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-5:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-17:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-23:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-21:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-46:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-13:Read 10267 from https://www.jython.org
# ForkPoolWorker-25:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-24:Read 10267 from https://www.jython.org
# ForkPoolWorker-38:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-63:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-43:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-50:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-56:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-37:Read 10267 from https://www.jython.org
# ForkPoolWorker-14:Read 10267 from https://www.jython.org
# ForkPoolWorker-45:Read 10267 from https://www.jython.org
# ForkPoolWorker-32:Read 10267 from https://www.jython.org
# ForkPoolWorker-53:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-2:Read 10267 from https://www.jython.org
# ForkPoolWorker-1:Read 10267 from https://www.jython.org
# ForkPoolWorker-31:Read 10267 from https://www.jython.org
# ForkPoolWorker-40:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-8:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-3:Read 10267 from https://www.jython.org
# ForkPoolWorker-52:Read 278 from http://olympus.realpython.org/dice
# ForkPoolWorker-16:Read 10267 from https://www.jython.org
# ForkPoolWorker-64:Read 278 from http://olympus.realpython.org/dice
# Downloaded 160 in 19.97868585586548 seconds

# %% [markdown]
# ![](../asset/MProc.webp)

# %% [markdown]
# ## 如何加入CPU密集型的程序

# %%
import time


def cpu_bound(number):
    return sum(i * i for i in range(number))


def find_sums(numbers):
    for number in numbers:
        cpu_bound(number)


if __name__ == "__main__":
    numbers = [5_000_000 + x for x in range(20)]

    start_time = time.time()
    find_sums(numbers)
    duration = time.time() - start_time
    print(f"Duration {duration} seconds")
# Out:
# Duration 37.74378275871277 seconds

# %% [markdown]
# ![](../asset/CPUBound.webp)

# %% [markdown]
# 改造成多进程版本

# %%
# %load src/multiprocessing-cpu.py
import multiprocessing
import time


def cpu_bound(number):
    return sum(i * i for i in range(number))


def find_sums(numbers):
    with multiprocessing.Pool() as pool:
        pool.map(cpu_bound, numbers)


if __name__ == "__main__":
    numbers = [5_000_000 + x for x in range(20)]

    start_time = time.time()
    find_sums(numbers)
    duration = time.time() - start_time
    print(f"Duration {duration} seconds")
# Out:
# Duration 3.974608898162842 seconds

# %%
# !python src/multiprocessing-cpu.py
# Out:
# Duration 4.311970472335815 seconds

# %% [markdown]
# ![](../asset/CPUMP.webp)

# %% [markdown]
# > Premature optimization is the root of all evil (or at least most of it) in programming.
# >                                                                                    - Donald Knuth

# %% [markdown]
# # 面试题
# ## 说说进程、线程和协程之间的区别和举例说明在实际使用的中选择标准
